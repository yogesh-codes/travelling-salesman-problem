# %% [markdown]
# ## zz (ignore)

# %% [markdown]
# ### (if needed) Graph- Distribution of the 'shortest Distances' values

# %%
sns.histplot(combined_dfs["distance"],label="distance",bins=25)
plt.legend()
plt.title("Distribution of distances as determined by A*")
plt.show()


plt.violinplot([combined_dfs["distance"]])
plt.boxplot([combined_dfs["distance"]],labels=["Distribution of the distances (as determined by A* algorithm)"])
plt.show()
display(combined_dfs["distance"].describe())
print (f"Therefore, For a 20x20 grid, the shortest distance bw \
a given pair of nodes is around {combined_dfs['distance'].mean():.2f} units.")
# Out:
# count    120.000000
# mean      12.366667
# std        6.615405
# min        2.000000
# 25%        7.000000
# 50%       12.000000
# 75%       16.000000
# max       31.000000
# Name: distance, dtype: float64
# Therefore, For a 20x20 grid, the shortest distance bw a given pair of nodes is around 12.37 units.

# %% [markdown]
# ### (if needed) STATISTICS- GROUPED BY SIMULATION

# %% [raw]
# print(n_simulations)
# print(f"Result of the {n_simulations} runs")
# L=[]
# for i in range(n):
#     L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["distance"],name=f"EXPERIMENT{i}- avg shortest distance"))
#
# df_distances=pd.concat(L,axis=1).T
# display(df_distances[["mean"]])
#
# L=[]
# for i in range(n):
#     L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["steps_to_converge"],name=f"EXPERIMENT{i}- no of steps to converge"))
#
# df_steps=pd.concat(L,axis=1).T
# display(df_steps[["mean"]])

# %% [raw]
# plt.violinplot([df_distances["mean"]])
# plt.boxplot([df_distances["mean"]])
# plt.title("Distribution of the Distances grouped by simulation")
# plt.show()
# df_distances[["mean","std","min","25%","50%","75%","max"]]
# print (f"Therefore, For a 20x20 grid, the shortest distance bw a given pair of nodes is around {df_distances['mean'].mean():.2f} units.")

# %% [raw]
# plt.violinplot([df_steps["mean"]])
# plt.boxplot([df_steps["mean"]],labels=["avg"])
# plt.title("Distribution of no of steps to convergence")
# plt.show()
# display(df_steps[["mean","std","min","25%","50%","75%","max"]])
#
# print (f"Therefore, For a 20x20 grid, the estimated mean no of steps to convergence is around {df_steps['50%'].median():.2f}. ")

# %%
## zz (ignore)

### (if needed) Graph- Distribution of the 'shortest Distances' values

sns.histplot(combined_dfs["distance"],label="distance",bins=25)
plt.legend()
plt.title("Distribution of distances as determined by A*")
plt.show()


plt.violinplot([combined_dfs["distance"]])
plt.boxplot([combined_dfs["distance"]],labels=["Distribution of the distances (as determined by A* algorithm)"])
plt.show()
display(combined_dfs["distance"].describe())
print (f"Therefore, For a 20x20 grid, the shortest distance bw \
a given pair of nodes is around {combined_dfs['distance'].mean():.2f} units.")

### (if needed) STATISTICS- GROUPED BY SIMULATION

 

print(n_simulations)
print(f"Result of the {n_simulations} runs")
L=[]
for i in range(n):
    L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["distance"],name=f"EXPERIMENT{i}- avg shortest distance"))
    
df_distances=pd.concat(L,axis=1).T
display(df_distances[["mean"]])

L=[]
for i in range(n):
    L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["steps_to_converge"],name=f"EXPERIMENT{i}- no of steps to converge"))
    
df_steps=pd.concat(L,axis=1).T
display(df_steps[["mean"]])




plt.violinplot([df_distances["mean"]])
plt.boxplot([df_distances["mean"]])
plt.title("Distribution of the Distances grouped by simulation")
plt.show()
df_distances[["mean","std","min","25%","50%","75%","max"]]
print (f"Therefore, For a 20x20 grid, the shortest distance bw a given pair of nodes is around {df_distances['mean'].mean():.2f} units.")



plt.violinplot([df_steps["mean"]])
plt.boxplot([df_steps["mean"]],labels=["avg"])
plt.title("Distribution of no of steps to convergence")
plt.show()
display(df_steps[["mean","std","min","25%","50%","75%","max"]])

print (f"Therefore, For a 20x20 grid, the estimated mean no of steps to convergence is around {df_steps['50%'].median():.2f}. ")

## zz (ignore)

### (if needed) Graph- Distribution of the 'shortest Distances' values

sns.histplot(combined_dfs["distance"],label="distance",bins=25)
plt.legend()
plt.title("Distribution of distances as determined by A*")
plt.show()


plt.violinplot([combined_dfs["distance"]])
plt.boxplot([combined_dfs["distance"]],labels=["Distribution of the distances (as determined by A* algorithm)"])
plt.show()
display(combined_dfs["distance"].describe())
print (f"Therefore, For a 20x20 grid, the shortest distance bw \
a given pair of nodes is around {combined_dfs['distance'].mean():.2f} units.")

### (if needed) STATISTICS- GROUPED BY SIMULATION

 

print(n_simulations)
print(f"Result of the {n_simulations} runs")
L=[]
for i in range(n):
    L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["distance"],name=f"EXPERIMENT{i}- avg shortest distance"))
    
df_distances=pd.concat(L,axis=1).T
display(df_distances[["mean"]])

L=[]
for i in range(n):
    L.append(pd.Series(summarised_dfs[f"SIMULATION{i}"]["steps_to_converge"],name=f"EXPERIMENT{i}- no of steps to converge"))
    
df_steps=pd.concat(L,axis=1).T
display(df_steps[["mean"]])




plt.violinplot([df_distances["mean"]])
plt.boxplot([df_distances["mean"]])
plt.title("Distribution of the Distances grouped by simulation")
plt.show()
df_distances[["mean","std","min","25%","50%","75%","max"]]
print (f"Therefore, For a 20x20 grid, the shortest distance bw a given pair of nodes is around {df_distances['mean'].mean():.2f} units.")



plt.violinplot([df_steps["mean"]])
plt.boxplot([df_steps["mean"]],labels=["avg"])
plt.title("Distribution of no of steps to convergence")
plt.show()
display(df_steps[["mean","std","min","25%","50%","75%","max"]])

print (f"Therefore, For a 20x20 grid, the estimated mean no of steps to convergence is around {df_steps['50%'].median():.2f}. ")
